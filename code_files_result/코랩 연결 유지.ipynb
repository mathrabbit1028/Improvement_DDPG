# %%
import pyautogui
import time

# 화면의 해상도 얻기
screen_width, screen_height = pyautogui.size()

print(f"The screen resolution is {screen_width}x{screen_height}")


# 화면의 (x, y) 위치를 클릭
while True:
    pyautogui.click(480, 540)
    pyautogui.click(1440, 540)
    time.sleep(5)
